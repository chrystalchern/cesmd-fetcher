# %% [markdown]
# ## Get NSMP Records

# %%
import search
from pathlib import Path
import json
import pandas as pd
import pprint
pp = pprint.PrettyPrinter().pprint

# %% [markdown]
# ### NSMP Buildings
# https://earthquake.usgs.gov/monitoring/nsmp/arrays/#Buildings has 96.
#
# https://www.strongmotioncenter.org/wserv/stations/query?netid=NP&sttype=B&format=json&nodata=404 has 140.

# %%
# USGS
with open("./NSMP/NSMP_buildings.html", 'r') as readfile:
    NSMP_buildings_usgs = pd.read_html(readfile)[0]
NSMP_buildings_usgs = NSMP_buildings_usgs.set_index('Station Code').to_dict('index')
for key in list(NSMP_buildings_usgs):
    NSMP_buildings_usgs[key.split(" ")[0]] = NSMP_buildings_usgs.pop(key)  # Remove any footnoted keys
print(len(NSMP_buildings_usgs), list(NSMP_buildings_usgs.items())[:3])

BUILDINGS = {value['Network Code']+key:value['Name'] for key,value in NSMP_buildings_usgs.items()}

# CESMD Web Services
with open("./NSMP/NSMP_buildings_web.json", 'r') as readfile:
    NSMP_buildings_web = json.load(readfile)
NSMP_buildings_web = {station['properties']['code']:station['properties']['name'] for station in NSMP_buildings_web['features']}
print(len(NSMP_buildings_web), list(NSMP_buildings_web.items())[:3])
# Out:
# 96 [('1103', {'Network Code': 'NP', 'Name': 'Great Western Savings', 'City': 'Berkeley', 'State': 'CA', 'Location': '37.87, -122.2688', 'Site Agency': 'Commercial', 'Channels': 16, 'Links': 'map, data, photo and schematic'}), ('1225', {'Network Code': 'NP', 'Name': 'VAMC, Bldg 2', 'City': 'San Francisco', 'State': 'CA', 'Location': '37.7827, -122.5048', 'Site Agency': 'U.S. Dept. of Veterans Affairs', 'Channels': 6, 'Links': 'map, data, photo and schematic'}), ('1226', {'Network Code': 'NP', 'Name': 'VAMC, Bldg 62', 'City': 'Livermore', 'State': 'CA', 'Location': '37.6255, -121.763', 'Site Agency': 'U.S. Dept. of Veterans Affairs', 'Channels': 24, 'Links': 'map, data, photo and schematic'})]
# 140 [('8040', 'Anchorage - R B Atwood Bldg'), ('2202', 'MT:Helena;Carroll Coll'), ('2205', 'MT:Bozeman;Montana St Univ')]

# %% [markdown]
# ### NSMP Bridges
#
# https://earthquake.usgs.gov/monitoring/nsmp/arrays/#Bridges has 16.
#
# https://www.strongmotioncenter.org/wserv/stations/query?netid=NP&sttype=Br&format=json&nodata=404 has 2.

# %%
# USGS
with open("./NSMP/NSMP_bridges.html", 'r') as readfile:
    NSMP_bridges_usgs = pd.read_html(readfile)[0]
NSMP_bridges_usgs = NSMP_bridges_usgs.set_index('Station Code').to_dict('index')
print(len(NSMP_bridges_usgs), list(NSMP_bridges_usgs.items())[:3])

BRIDGES = {value['Network Code']+key:value['Name'] for key,value in NSMP_bridges_usgs.items()}

# CESMD Web Services
with open("./NSMP/NSMP_bridges_web.json", 'r') as readfile:
    NSMP_bridges_web = json.load(readfile)
NSMP_bridges_web = {station['properties']['code']:station['properties']['name'] for station in NSMP_bridges_web['features']}
print(len(NSMP_bridges_web), list(NSMP_bridges_web.items())[:3])
# Out:
# 16 [('1571', {'Network Code': 'NP', 'Name': '101/280/680 Freeway Crossing', 'City': 'San Jose', 'State': 'CA', 'Location': '37.3393, -121.852', 'Site Agency': 'U.S. Geological Survey', 'Channels': 24, 'Links': 'map, data, photo and schematic'}), ('5235', {'Network Code': 'NP', 'Name': 'Santa Ana River Bridge', 'City': 'Riverside', 'State': 'CA', 'Location': '33.9695, -117.4484', 'Site Agency': 'Metropolitan Water District of So. Cal.', 'Channels': 15, 'Links': 'map, data, photo and schematic'}), ('7013', {'Network Code': 'NP', 'Name': 'Clackamas Highway Connection', 'City': 'Milwaukie', 'State': 'OR', 'Location': '45.45, -122.6416', 'Site Agency': 'Oregon Dept. of Transportation', 'Channels': 12, 'Links': 'map, data, photo and schematic'})]
# 2 [('5235', 'Riverside; Santa Ana River Bridge'), ('1571', 'San Jose; Interchange 101/280/680')]

# %%
building_dir = Path("./NSMP/buildings/motions_original")
if not building_dir.exists():
    Path.mkdir(building_dir)
bridge_dir = Path("./NSMP/bridges/motions_original")
if not bridge_dir.exists():
    Path.mkdir(bridge_dir)

# %%
update_files = False

# %%
BUILDING_RECORDS = {}
if update_files:
    for key in BUILDINGS.keys():
        print(key, ':', BUILDINGS[key])
        try:
            search.get_records(str(building_dir)+"/"+key, "cchern@berkeley.edu", station_code=key, process_level="processed", include_inactive=True)
        except Exception as e:
            print(e)
            continue
        BUILDING_RECORDS[key] = BUILDINGS[key]
    with open(building_dir/"station_names.json", "w") as writefile:
        json.dump(BUILDING_RECORDS, writefile)
else:
    with open(building_dir/"station_names.json", "r") as readfile:
        BUILDING_RECORDS = json.load(readfile)

# %%
BUILDING_RECORDS
# Out:
# {'NP1103': 'Great Western Savings',
#  'NP1225': 'VAMC, Bldg 2',
#  'NP1226': 'VAMC, Bldg 62',
#  'NP1227': 'VAMC, Bldg 1',
#  'NP1230': 'VAMC, Bldg 137',
#  'NP1239': 'Transamerica Tower',
#  'NP1446': 'Chevron Building',
#  'NP1662': 'Pacific Park Plaza',
#  'NP1745': 'USGS McKelvey Bldg',
#  'NP1811': 'Channing House',
#  'NP1812': 'City Hall',
#  'NP1833': 'San Francisco, Moscone West',
#  'NP1867': 'UC Berkeley Hearst Mining Bldg',
#  'NP2210': 'VAMC, Bldg 1',
#  'NP2544': 'Charleston Place Hotel',
#  'NP2656': 'MIT Green Bldg 54',
#  'NP2716': 'Hilton Hotel',
#  'NP2838': 'Bank of Hawaii',
#  'NP3095': 'VAMC, New Patient Bed Bldg',
#  'NP3096': 'VAMC, Bldg 10',
#  'NP5082': 'Wadsworth VAMC Bldg 500',
#  'NP5106': 'VAMC, Bldg 126',
#  'NP5229': 'VAMC',
#  'NP5233': '1100 Wilshire Blvd.',
#  'NP5239': '12440 Imperial Highway',
#  'NP5243': 'FAA Building',
#  'NP5245': 'County Services Center',
#  'NP5284': 'Lowe Residence',
#  'NP5405': 'UCLA, Factor Building',
#  'NP5406': 'CSU Engineering Bldg',
#  'NP5407': 'Caltech Millikan Library',
#  'NP5410': 'JPL Building 179',
#  'NP5439': 'MWD Headquarters',
#  'NP5446': 'UC Irvine, IT2 Bldg',
#  'NP5449': 'Federal Building',
#  'NP5478': 'Sepulveda VAMC, Bldg 10',
#  'NP5485': 'VAMC West LA, Bldg 114',
#  'NP5501': 'UCLA Boelter Hall',
#  'CE58389': 'Rincon Hill Tower',
#  'NP7010': 'Crowne Plaza Hotel',
#  'NP7215': 'Wallace Bennett Federal Bldg.',
#  'NP7235': 'Fort Harrison VAMC, Bldg154',
#  'NP7237': 'VAMC, Bldg 14',
#  'NP7413': 'VAMC, Bldg 1',
#  'NP8016': 'BP Building',
#  'NP8040': 'Robert B Atwood Bldg',
#  'NP8042': 'Frontier Building',
#  'NP8045': 'VAMC',
#  'PRB03L': 'El Castillo Building',
#  'WRSAC': 'Sacramento Resource Building'}

# %%
BRIDGE_RECORDS = {}
if update_files:
    for key in BRIDGES.keys():
        print(key, ':', BRIDGES[key])
        try:
            search.get_records(str(bridge_dir)+"/"+key, "cchern@berkeley.edu", station_code=key, process_level="processed", include_inactive=True)
        except Exception as e:
            print(e)
            continue
        BRIDGE_RECORDS[key] = BRIDGES[key]
    with open(bridge_dir/"station_names.json", "w") as writefile:
        json.dump(BRIDGE_RECORDS, writefile)
else:
    with open(bridge_dir/"station_names.json", "r") as readfile:
        BRIDGE_RECORDS = json.load(readfile)

# %%
BRIDGE_RECORDS
# Out:
# {'NP1571': '101/280/680 Freeway Crossing', 'NP8043': 'Port Access Bridge'}

# %%
print(len(BUILDING_RECORDS), len(BRIDGE_RECORDS))
# Out:
# 50 2

# %% [markdown]
# ## Move records to top levels of unzipped folders

# %%
import glob, os
from zipfile import ZipFile

# %%
extract_new = False

# %%
if extract_new:
    for record_dir in [building_dir, bridge_dir]:
        for cesmd_zip in glob.glob(str(record_dir)+"/*.zip"):
            newdir = cesmd_zip[:-4]
            with ZipFile(cesmd_zip) as zObject: 
                zObject.extractall(path="./"+newdir)

# %%
move_new = False

# %%
if move_new:

    def delete_empty_folders(root):
        deleted = set()
        for current_dir, subdirs, files in os.walk(root, topdown=False):
            still_has_subdirs = False
            for subdir in subdirs:
                if os.path.join(current_dir, subdir) not in deleted:
                    still_has_subdirs = True
                    break
            if not any(files) and not still_has_subdirs:
                os.rmdir(current_dir)
                deleted.add(current_dir)
        return deleted

    for RECORDS,record_dir in zip([BUILDING_RECORDS, BRIDGE_RECORDS], [building_dir, bridge_dir]):
        for key in RECORDS.keys():
            for record in glob.glob(str(record_dir)+"/"+key+"/*/*/*.[zZ][iI][pP]"):
                os.replace(record, str(record_dir)+"/"+key+"/"+os.path.basename(record).lower())
    
    delete_empty_folders(".")

# %%
count_records = False

# %%
if count_records:
    BUILDING_RECORD_COUNT = {}
    BRIDGE_RECORD_COUNT = {}
    for RECORDS,RECORD_COUNT,record_dir in zip([BUILDING_RECORDS, BRIDGE_RECORDS], [BUILDING_RECORD_COUNT,BRIDGE_RECORD_COUNT], [building_dir, bridge_dir]):
        for key in RECORDS.keys():
            RECORD_COUNT[key] = len(glob.glob(str(record_dir)+"/"+key+"/*.zip"))
    with open(record_dir/"record_counts.json", "w") as writefile:
        json.dump(RECORD_COUNT, writefile)
else:
    with open(building_dir/"record_counts.json", "r") as readfile:
        BUILDING_RECORD_COUNT = json.load(readfile)
    with open(bridge_dir/"record_counts.json", "r") as readfile:
        BRIDGE_RECORD_COUNT = json.load(readfile)

pp(BUILDING_RECORD_COUNT)
pp(BRIDGE_RECORD_COUNT)
print(len([key for key,value in BUILDING_RECORD_COUNT.items() if value>=5]))
print(len([key for key,value in BRIDGE_RECORD_COUNT.items() if value>=5]))
# Out:
# {'CE58389': 2,
#  'NP1103': 3,
#  'NP1225': 1,
#  'NP1226': 4,
#  'NP1227': 1,
#  'NP1230': 1,
#  'NP1239': 1,
#  'NP1446': 1,
#  'NP1662': 17,
#  'NP1745': 3,
#  'NP1811': 2,
#  'NP1812': 1,
#  'NP1833': 1,
#  'NP1867': 2,
#  'NP2210': 2,
#  'NP2544': 1,
#  'NP2656': 1,
#  'NP2716': 11,
#  'NP2838': 40,
#  'NP3095': 13,
#  'NP3096': 1,
#  'NP5082': 6,
#  'NP5106': 7,
#  'NP5229': 9,
#  'NP5233': 1,
#  'NP5239': 1,
#  'NP5243': 3,
#  'NP5245': 13,
#  'NP5284': 1,
#  'NP5405': 10,
#  'NP5406': 1,
#  'NP5407': 3,
#  'NP5410': 1,
#  'NP5439': 1,
#  'NP5446': 1,
#  'NP5449': 1,
#  'NP5478': 7,
#  'NP5485': 12,
#  'NP5501': 4,
#  'NP7010': 1,
#  'NP7215': 2,
#  'NP7235': 1,
#  'NP7237': 1,
#  'NP7413': 2,
#  'NP8016': 17,
#  'NP8040': 32,
#  'NP8042': 16,
#  'NP8045': 24,
#  'PRB03L': 12,
#  'WRSAC': 1}
# {'NP1571': 2, 'NP8043': 20}
# 16
# 1

# %%
summarize_new = True

# %%
import numpy as np
def np_encoder(object):
    if isinstance(object, np.generic):
        return object.item()

# %%
if summarize_new:
    import quakeio
    import json
    for RECORDS,record_dir in zip([BUILDING_RECORDS, BRIDGE_RECORDS], [building_dir, bridge_dir]):
        for key in RECORDS.keys():  
            events = []
            for file in glob.glob(str(record_dir)+"/"+key+"/*.zip"):
                print(f"Reading {file}")
                with ZipFile(file, "r") as readfile:
                    if any('.smc' in name for name in readfile.namelist()):
                        parser = 'smc.read_event'
                    else:
                        parser = None
                try:
                    events.append(
                        quakeio.read(file, summarize=True, parser=parser).serialize(serialize_data=False)
                    )
                except Exception as e:
                    print(e)
                    print(f"failed to read {file}")
                    # raise e
            # print(events)
            with open(str(record_dir)+"/"+key+"_meta.json", "w") as writefile:
                json.dump(events, writefile, default=np_encoder)
# Out:
# Reading NSMP/buildings/motions_original/NP1103/berkeley_04jan2018_72948801_np1103p.zip
.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5106/ci38996632_np5106p.zip
# Reading NSMP/buildings/motions_original/NP5229/anza_12jun2005_np05229p.zip
# Reading NSMP/buildings/motions_original/NP5229/borregosprings_10jun2016_37374687_np5229p.zip
# Reading NSMP/buildings/motions_original/NP5229/ci38443183_np5229p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5229/ci38443183_np5229p.zip
# Reading NSMP/buildings/motions_original/NP5229/ci38457511_np5229p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5229/ci38457511_np5229p.zip
# Reading NSMP/buildings/motions_original/NP5229/ci38457775_np5229p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5229/ci38457775_np5229p.zip
# Reading NSMP/buildings/motions_original/NP5229/ci38695658_np5229p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5229/ci38695658_np5229p.zip
# Reading NSMP/buildings/motions_original/NP5229/ci39126079_np5229p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5229/ci39126079_np5229p.zip
# Reading NSMP/buildings/motions_original/NP5229/ci39462536_np5229p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5229/ci39462536_np5229p.zip
# Reading NSMP/buildings/motions_original/NP5229/yucaipa_16jun2005_np05229p.zip
# Reading NSMP/buildings/motions_original/NP5233/sierramadre91_np05233p.zip
# Reading NSMP/buildings/motions_original/NP5239/hectormine99_np05239p.zip
# Reading NSMP/buildings/motions_original/NP5243/calexico_04apr2010_14607652_np05243p.zip
# Reading NSMP/buildings/motions_original/NP5243/inglewood_17may2009_np05243p.zip
# Reading NSMP/buildings/motions_original/NP5243/yucaipa_16jun2005_np05243p.zip
# Reading NSMP/buildings/motions_original/NP5245/ci38443183_np5245p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5245/ci38443183_np5245p.zip
# Reading NSMP/buildings/motions_original/NP5245/ci38450263_np5245p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5245/ci38450263_np5245p.zip
# Reading NSMP/buildings/motions_original/NP5245/ci38457487_np5245p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5245/ci38457487_np5245p.zip
# Reading NSMP/buildings/motions_original/NP5245/ci38457703_np5245p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5245/ci38457703_np5245p.zip
# Reading NSMP/buildings/motions_original/NP5245/ci38457815_np5245p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5245/ci38457815_np5245p.zip
# Reading NSMP/buildings/motions_original/NP5245/ci38460311_np5245p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5245/ci38460311_np5245p.zip
# Reading NSMP/buildings/motions_original/NP5245/ci38460967_np5245p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5245/ci38460967_np5245p.zip
# Reading NSMP/buildings/motions_original/NP5245/ci38460975_np5245p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5245/ci38460975_np5245p.zip
# Reading NSMP/buildings/motions_original/NP5245/ci38695658_np5245p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5245/ci38695658_np5245p.zip
# Reading NSMP/buildings/motions_original/NP5245/ci38996632_np5245p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5245/ci38996632_np5245p.zip
# Reading NSMP/buildings/motions_original/NP5245/ci39126079_np5245p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5245/ci39126079_np5245p.zip
# Reading NSMP/buildings/motions_original/NP5245/ci39281440_np5245p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5245/ci39281440_np5245p.zip
# Reading NSMP/buildings/motions_original/NP5245/ci39493944_np5245p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5245/ci39493944_np5245p.zip
# Reading NSMP/buildings/motions_original/NP5284/bigbear92_np05284p.zip
# Reading NSMP/buildings/motions_original/NP5405/ci37219164_np5405p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5405/ci37219164_np5405p.zip
# Reading NSMP/buildings/motions_original/NP5405/ci38457559_np5405p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5405/ci38457559_np5405p.zip
# Reading NSMP/buildings/motions_original/NP5405/ci38457583_np5405p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5405/ci38457583_np5405p.zip
# Reading NSMP/buildings/motions_original/NP5405/ci38457591_np5405p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5405/ci38457591_np5405p.zip
# Reading NSMP/buildings/motions_original/NP5405/ci38457599_np5405p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5405/ci38457599_np5405p.zip
# Reading NSMP/buildings/motions_original/NP5405/ci38457615_np5405p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5405/ci38457615_np5405p.zip
# Reading NSMP/buildings/motions_original/NP5405/ci38457679_np5405p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5405/ci38457679_np5405p.zip
# Reading NSMP/buildings/motions_original/NP5405/ci38457687_np5405p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5405/ci38457687_np5405p.zip
# Reading NSMP/buildings/motions_original/NP5405/ci38457703_np5405p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5405/ci38457703_np5405p.zip
# Reading NSMP/buildings/motions_original/NP5405/hectormine99_np05405p.zip
# Reading NSMP/buildings/motions_original/NP5406/westwoodvillage_01jun2014_15507801_np5406p.zip
# Reading NSMP/buildings/motions_original/NP5407/ci38443183_np5407p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5407/ci38443183_np5407p.zip
# Reading NSMP/buildings/motions_original/NP5407/ci38457511_np5407p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5407/ci38457511_np5407p.zip
# Reading NSMP/buildings/motions_original/NP5407/ci38695658_np5407p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5407/ci38695658_np5407p.zip
# Reading NSMP/buildings/motions_original/NP5410/hectormine99_np05410p.zip
# Reading NSMP/buildings/motions_original/NP5439/lahabra_28mar2014_15481673_np5439p.zip
# Reading NSMP/buildings/motions_original/NP5446/ci38695658_np5446p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5446/ci38695658_np5446p.zip
# Reading NSMP/buildings/motions_original/NP5449/lahabra_28mar2014_15481673_np5449p.zip
# Reading NSMP/buildings/motions_original/NP5478/ci38695658_np5478p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5478/ci38695658_np5478p.zip
# Reading NSMP/buildings/motions_original/NP5478/ci39322287_np5478p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5478/ci39322287_np5478p.zip
# Reading NSMP/buildings/motions_original/NP5478/ci39462536_np5478p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5478/ci39462536_np5478p.zip
# Reading NSMP/buildings/motions_original/NP5478/ci39838928_np5478p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5478/ci39838928_np5478p.zip
# Reading NSMP/buildings/motions_original/NP5478/ci40161279_np5478p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5478/ci40161279_np5478p.zip
# Reading NSMP/buildings/motions_original/NP5478/ci40453591_np5478p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5478/ci40453591_np5478p.zip
# Reading NSMP/buildings/motions_original/NP5478/ci40664632_np5478p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5478/ci40664632_np5478p.zip
# Reading NSMP/buildings/motions_original/NP5485/ci38457487_np5485p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5485/ci38457487_np5485p.zip
# Reading NSMP/buildings/motions_original/NP5485/ci38457511_np5485p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5485/ci38457511_np5485p.zip
# Reading NSMP/buildings/motions_original/NP5485/ci38457583_np5485p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5485/ci38457583_np5485p.zip
# Reading NSMP/buildings/motions_original/NP5485/ci38457591_np5485p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5485/ci38457591_np5485p.zip
# Reading NSMP/buildings/motions_original/NP5485/ci38457599_np5485p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5485/ci38457599_np5485p.zip
# Reading NSMP/buildings/motions_original/NP5485/ci38457615_np5485p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5485/ci38457615_np5485p.zip
# Reading NSMP/buildings/motions_original/NP5485/ci38457679_np5485p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5485/ci38457679_np5485p.zip
# Reading NSMP/buildings/motions_original/NP5485/ci38457687_np5485p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5485/ci38457687_np5485p.zip
# Reading NSMP/buildings/motions_original/NP5485/ci38457703_np5485p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5485/ci38457703_np5485p.zip
# Reading NSMP/buildings/motions_original/NP5485/pt.ferminsanpedro_30dec2014_37300400_np5485p.zip
# Reading NSMP/buildings/motions_original/NP5485/viewpark-windsorhills_03may2015_37374008_np5485p.zip
# Reading NSMP/buildings/motions_original/NP5485/westwoodvillage_01jun2014_15507801_np5485p.zip
# Reading NSMP/buildings/motions_original/NP5501/ci38443183_np5501p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5501/ci38443183_np5501p.zip
# Reading NSMP/buildings/motions_original/NP5501/ci38450263_np5501p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5501/ci38450263_np5501p.zip
# Reading NSMP/buildings/motions_original/NP5501/ci39322287_np5501p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5501/ci39322287_np5501p.zip
# Reading NSMP/buildings/motions_original/NP5501/ci39838928_np5501p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP5501/ci39838928_np5501p.zip
# Reading NSMP/buildings/motions_original/CE58389/berkeley_04jan2018_72948801_ce58389p.zip
# Reading NSMP/buildings/motions_original/CE58389/southnapa_24aug2014_72282711_ce58389p.zip
# Reading NSMP/buildings/motions_original/NP7010/lincolnmontana_06jul2017_10009757_np7010p.zip
# Reading NSMP/buildings/motions_original/NP7215/sodaspringsidaho_02sep2017_2000aekg_np7215p.zip
# Reading NSMP/buildings/motions_original/NP7215/uu60363602_np7215p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP7215/uu60363602_np7215p.zip
# Reading NSMP/buildings/motions_original/NP7235/lincolnmontana_06jul2017_10009757_np7235p.zip
# Reading NSMP/buildings/motions_original/NP7237/uu60363602_np7237p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP7237/uu60363602_np7237p.zip
# Reading NSMP/buildings/motions_original/NP7413/cushingoklahoma_07nov2016_us100075y8_np7413p.zip
# Reading NSMP/buildings/motions_original/NP7413/pawneeoklahoma_03sep2016_us10006jxs_np7413p.zip
# Reading NSMP/buildings/motions_original/NP8016/ak018fcpk9xi_np8016p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8016/ak018fcpk9xi_np8016p.zip
# Reading NSMP/buildings/motions_original/NP8016/ak0191pccr7_np8016p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8016/ak0191pccr7_np8016p.zip
# Reading NSMP/buildings/motions_original/NP8016/ak020ec6yfo7_np8016p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8016/ak020ec6yfo7_np8016p.zip
# Reading NSMP/buildings/motions_original/NP8016/ak0212o88mof_np8016p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8016/ak0212o88mof_np8016p.zip
# Reading NSMP/buildings/motions_original/NP8016/ak20419042_np8016p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8016/ak20419042_np8016p.zip
# Reading NSMP/buildings/motions_original/NP8016/ak20419870_np8016p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8016/ak20419870_np8016p.zip
# Reading NSMP/buildings/motions_original/NP8016/ak20421432_np8016p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8016/ak20421432_np8016p.zip
# Reading NSMP/buildings/motions_original/NP8016/ak20421672_np8016p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8016/ak20421672_np8016p.zip
# Reading NSMP/buildings/motions_original/NP8016/ak20421831_np8016p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8016/ak20421831_np8016p.zip
# Reading NSMP/buildings/motions_original/NP8016/ak20428017_np8016p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8016/ak20428017_np8016p.zip
# Reading NSMP/buildings/motions_original/NP8016/ak20453123_np8016p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8016/ak20453123_np8016p.zip
# Reading NSMP/buildings/motions_original/NP8016/ak20477170_np8016p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP
.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8042/ak20419042_np8042p.zip
# Reading NSMP/buildings/motions_original/NP8042/ak20428017_np8042p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8042/ak20428017_np8042p.zip
# Reading NSMP/buildings/motions_original/NP8042/ak20453123_np8042p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8042/ak20453123_np8042p.zip
# Reading NSMP/buildings/motions_original/NP8042/ak20477170_np8042p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8042/ak20477170_np8042p.zip
# Reading NSMP/buildings/motions_original/NP8042/ak20556108_np8042p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8042/ak20556108_np8042p.zip
# Reading NSMP/buildings/motions_original/NP8042/iniskinalaska_24jan2016_10004gqp_np8042p.zip
# Reading NSMP/buildings/motions_original/NP8042/us1000hyfh_np8042p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8042/us1000hyfh_np8042p.zip
# Reading NSMP/buildings/motions_original/NP8042/willowak_25sep2014_11401855_np8042p.zip
# Reading NSMP/buildings/motions_original/NP8045/ak018fcpk9xi_np8045p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8045/ak018fcpk9xi_np8045p.zip
# Reading NSMP/buildings/motions_original/NP8045/ak0191pccr7_np8045p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8045/ak0191pccr7_np8045p.zip
# Reading NSMP/buildings/motions_original/NP8045/ak019lrs7iu_np8045p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8045/ak019lrs7iu_np8045p.zip
# Reading NSMP/buildings/motions_original/NP8045/ak020ec6yfo7_np8045p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8045/ak020ec6yfo7_np8045p.zip
# Reading NSMP/buildings/motions_original/NP8045/ak0212o88mof_np8045p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8045/ak0212o88mof_np8045p.zip
# Reading NSMP/buildings/motions_original/NP8045/ak0214icukav_np8045p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8045/ak0214icukav_np8045p.zip
# Reading NSMP/buildings/motions_original/NP8045/ak0215dsbmgn_np8045p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8045/ak0215dsbmgn_np8045p.zip
# Reading NSMP/buildings/motions_original/NP8045/ak0216xu2rod_np8045p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8045/ak0216xu2rod_np8045p.zip
# Reading NSMP/buildings/motions_original/NP8045/ak02239qtmiy_np8045p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8045/ak02239qtmiy_np8045p.zip
# Reading NSMP/buildings/motions_original/NP8045/ak0228vb1a7q_np8045p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8045/ak0228vb1a7q_np8045p.zip
# Reading NSMP/buildings/motions_original/NP8045/ak022esj2eua_np8045p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8045/ak022esj2eua_np8045p.zip
# Reading NSMP/buildings/motions_original/NP8045/ak0231itcv2l_np8045p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8045/ak0231itcv2l_np8045p.zip
# Reading NSMP/buildings/motions_original/NP8045/ak20419042_np8045p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8045/ak20419042_np8045p.zip
# Reading NSMP/buildings/motions_original/NP8045/ak20419870_np8045p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8045/ak20419870_np8045p.zip
# Reading NSMP/buildings/motions_original/NP8045/ak20421432_np8045p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8045/ak20421432_np8045p.zip
# Reading NSMP/buildings/motions_original/NP8045/ak20421672_np8045p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8045/ak20421672_np8045p.zip
# Reading NSMP/buildings/motions_original/NP8045/ak20421831_np8045p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8045/ak20421831_np8045p.zip
# Reading NSMP/buildings/motions_original/NP8045/ak20453123_np8045p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8045/ak20453123_np8045p.zip
# Reading NSMP/buildings/motions_original/NP8045/ak20477170_np8045p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8045/ak20477170_np8045p.zip
# Reading NSMP/buildings/motions_original/NP8045/ak20556108_np8045p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8045/ak20556108_np8045p.zip
# Reading NSMP/buildings/motions_original/NP8045/anchorageak_03dec2012_10612174_np8045p.zip
# Reading NSMP/buildings/motions_original/NP8045/iniskinalaska_24jan2016_10004gqp_np8045p.zip
# Reading NSMP/buildings/motions_original/NP8045/us1000hyfh_np8045p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8045/us1000hyfh_np8045p.zip
# Reading NSMP/buildings/motions_original/NP8045/us1000hyge_np8045p.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/NP8045/us1000hyge_np8045p.zip
# Reading NSMP/buildings/motions_original/PRB03L/pr2020006006_prb03lp.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/PRB03L/pr2020006006_prb03lp.zip
# Reading NSMP/buildings/motions_original/PRB03L/pr2020007010_prb03lp.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/PRB03L/pr2020007010_prb03lp.zip
# Reading NSMP/buildings/motions_original/PRB03L/pr2020011010_prb03lp.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/PRB03L/pr2020011010_prb03lp.zip
# Reading NSMP/buildings/motions_original/PRB03L/pr2020015008_prb03lp.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/PRB03L/pr2020015008_prb03lp.zip
# Reading NSMP/buildings/motions_original/PRB03L/pr2020123010_prb03lp.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/PRB03L/pr2020123010_prb03lp.zip
# Reading NSMP/buildings/motions_original/PRB03L/pr2020180001_prb03lp.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/PRB03L/pr2020180001_prb03lp.zip
# Reading NSMP/buildings/motions_original/PRB03L/pr2020185007_prb03lp.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/PRB03L/pr2020185007_prb03lp.zip
# Reading NSMP/buildings/motions_original/PRB03L/pr2020220000_prb03lp.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/PRB03L/pr2020220000_prb03lp.zip
# Reading NSMP/buildings/motions_original/PRB03L/us70006vll_prb03lp.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/PRB03L/us70006vll_prb03lp.zip
# Reading NSMP/buildings/motions_original/PRB03L/us70006vm9_prb03lp.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/PRB03L/us70006vm9_prb03lp.zip
# Reading NSMP/buildings/motions_original/PRB03L/us70006ye2_prb03lp.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/PRB03L/us70006ye2_prb03lp.zip
# Reading NSMP/buildings/motions_original/PRB03L/us7000ahjq_prb03lp.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/PRB03L/us7000ahjq_prb03lp.zip
# Reading NSMP/buildings/motions_original/WRSAC/ci38457511_wrsacp.zip
# max() arg is an empty sequence
# failed to read NSMP/buildings/motions_original/WRSAC/ci38457511_wrsacp.zip
# Reading NSMP/bridges/motions_original/NP1571/lomaprieta_17oct1989_np01571p.zip
# Reading NSMP/bridges/motions_original/NP1571/nc73799091_np1571p.zip
# max() arg is an empty sequence
# failed to read NSMP/bridges/motions_original/NP1571/nc73799091_np1571p.zip
# Reading NSMP/bridges/motions_original/NP8043/ak018fcpk9xi_np8043p.zip
# max() arg is an empty sequence
# failed to read NSMP/bridges/motions_original/NP8043/ak018fcpk9xi_np8043p.zip
# Reading NSMP/bridges/motions_original/NP8043/ak0191pccr7_np8043p.zip
# max() arg is an empty sequence
# failed to read NSMP/bridges/motions_original/NP8043/ak0191pccr7_np8043p.zip
# Reading NSMP/bridges/motions_original/NP8043/ak019lrs7iu_np8043p.zip
# max() arg is an empty sequence
# failed to read NSMP/bridges/motions_original/NP8043/ak019lrs7iu_np8043p.zip
# Reading NSMP/bridges/motions_original/NP8043/ak020ec6yfo7_np8043p.zip
# max() arg is an empty sequence
# failed to read NSMP/bridges/motions_original/NP8043/ak020ec6yfo7_np8043p.zip
# Reading NSMP/bridges/motions_original/NP8043/ak0212o88mof_np8043p.zip
# max() arg is an empty sequence
# failed to read NSMP/bridges/motions_original/NP8043/ak0212o88mof_np8043p.zip
# Reading NSMP/bridges/motions_original/NP8043/ak0215dsbmgn_np8043p.zip
# max() arg is an empty sequence
# failed to read NSMP/bridges/motions_original/NP8043/ak0215dsbmgn_np8043p.zip
# Reading NSMP/bridges/motions_original/NP8043/ak0216xu2rod_np8043p.zip
# max() arg is an empty sequence
# failed to read NSMP/bridges/motions_original/NP8043/ak0216xu2rod_np8043p.zip
# Reading NSMP/bridges/motions_original/NP8043/ak021gbh4rso_np8043p.zip
# max() arg is an empty sequence
# failed to read NSMP/bridges/motions_original/NP8043/ak021gbh4rso_np8043p.zip
# Reading NSMP/bridges/motions_original/NP8043/ak0228vb1a7q_np8043p.zip
# max() arg is an empty sequence
# failed to read NSMP/bridges/motions_original/NP8043/ak0228vb1a7q_np8043p.zip
# Reading NSMP/bridges/motions_original/NP8043/ak20419042_np8043p.zip
# max() arg is an empty sequence
# failed to read NSMP/bridges/motions_original/NP8043/ak20419042_np8043p.zip
# Reading NSMP/bridges/motions_original/NP8043/ak20421672_np8043p.zip
# max() arg is an empty sequence
# failed to read NSMP/bridges/motions_original/NP8043/ak20421672_np8043p.zip
# Reading NSMP/bridges/motions_original/NP8043/ak20421831_np8043p.zip
# max() arg is an empty sequence
# failed to read NSMP/bridges/motions_original/NP8043/ak20421831_np8043p.zip
# Reading NSMP/bridges/motions_original/NP8043/ak20428017_np8043p.zip
# max() arg is an empty sequence
# failed to read NSMP/bridges/motions_original/NP8043/ak20428017_np8043p.zip
# Reading NSMP/bridges/motions_original/NP8043/ak20453123_np8043p.zip
# max() arg is an empty sequence
# failed to read NSMP/bridges/motions_original/NP8043/ak20453123_np8043p.zip
# Reading NSMP/bridges/motions_original/NP8043/ak20477170_np8043p.zip
# max() arg is an empty sequence
# failed to read NSMP/bridges/motions_original/NP8043/ak20477170_np8043p.zip
# Reading NSMP/bridges/motions_original/NP8043/ak20556108_np8043p.zip
# max() arg is an empty sequence
# failed to read NSMP/bridges/motions_original/NP8043/ak20556108_np8043p.zip
# Reading NSMP/bridges/motions_original/NP8043/anchorageak_03dec2012_10612174_np8043p.zip
# Reading NSMP/bridges/motions_original/NP8043/kodiakalaska_23jan2018_2000cmy3_np8043p.zip
# 'u.smc'
# failed to read NSMP/bridges/motions_original/NP8043/kodiakalaska_23jan2018_2000cmy3_np8043p.zip
# Reading NSMP/bridges/motions_original/NP8043/us1000hyfh_np8043p.zip
# max() arg is an empty sequence
# failed to read NSMP/bridges/motions_original/NP8043/us1000hyfh_np8043p.zip
# Reading NSMP/bridges/motions_original/NP8043/us1000hyge_np8043p.zip
# max() arg is an empty sequence
# failed to read NSMP/bridges/motions_original/NP8043/us1000hyge_np8043p.zip
